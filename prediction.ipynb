# %%
# Step 1: Import Libraries and Load the Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
# Load the IMDB dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
# Load the pre-trained model with ReLU activation
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 500, 128)          1280000
#
#  simple_rnn_2 (SimpleRNN)    (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# ...
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.0765294 , -0.04895903,  0.05642875, ..., -0.01899079,
#           0.02473622,  0.00044728],
#         [ 0.02419006,  0.02891038, -0.0094237 , ...,  0.03206111,
#           0.02416968, -0.01024249],
#         [-0.00346715, -0.03032313, -0.01167982, ...,  0.01959065,
#           0.03123233, -0.06331155],
#         ...,
#         [ 0.02939172,  0.00292826,  0.02954462, ...,  0.04683698,
#           0.07496272, -0.05192222],
#         [ 0.06985339,  0.00248061, -0.05545266, ..., -0.04976642,
#          -0.07269984, -0.11083163],
#         [-0.07822992, -0.03801421,  0.00146004, ...,  0.02699921,
#          -0.00963374, -0.01788564]], dtype=float32),
#  array([[-0.13417184, -0.11625969, -0.06510165, ...,  0.11606652,
#          -0.01829457,  0.03417071],
#         [ 0.0042669 , -0.15749328,  0.03552296, ...,  0.00017249,
#           0.02637568, -0.13241188],
#         [ 0.09631698, -0.06329773, -0.10850494, ..., -0.12002493,
#           0.02124852, -0.07276414],
# ...

# %%
# Step 2: Helper Functions
# Function to decode reviews
# the below function is for decoding review 
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

# Function to preprocess user input
# when  a user gives input , we have to take that word, encode entire review , pad it, and get the padded review, then only can pass it to the model. 
# since embeddings is part of the model function, no need to do it in pre preocessing
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### Prediction  function

def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)

    prediction=model.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

# example_review= "The movie is a beautifully crafted film that delves deep into the complexities of love"
sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Positive
# Prediction Score: 0.9855631589889526
